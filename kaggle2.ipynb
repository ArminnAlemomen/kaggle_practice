# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dff = pd.read_csv("test_kaggle_two.csv")
dff
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
x_idtest = dff[['Id']]
x_test = dff[['OverallQual','OverallCond','YearBuilt','YearRemodAdd','ExterQual','BsmtQual','GarageCars','GarageArea','Fireplaces','FireplaceQu','GrLivArea','TotalBsmtSF','1stFlrSF','2ndFlrSF','LotArea','LotFrontage','FullBath','HalfBath','BsmtFullBath','PoolArea','KitchenQual']]

# %%
x_test['ExterQual'] = x_test['ExterQual'].map({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po': 1})
x_test['BsmtQual'] = x_test['BsmtQual'].map({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po': 1})
x_test['FireplaceQu'] = x_test['FireplaceQu'].map({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po': 1})
x_test['KitchenQual'] = x_test['KitchenQual'].map({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po': 1})
x_test['ExterQual'] = x_test['ExterQual'].fillna(x_test['ExterQual'].mean())
x_test['BsmtQual'] = x_test['BsmtQual'].fillna(x_test['BsmtQual'].mean())
x_test['FireplaceQu'] = x_test['FireplaceQu'].fillna(x_test['FireplaceQu'].mean())
x_test['KitchenQual'] = x_test['KitchenQual'].fillna(x_test['KitchenQual'].mean())
x_test['OverallQual'] = x_test['OverallQual'].fillna(x_test['OverallQual'].mean())
x_test['OverallCond'] = x_test['OverallCond'].fillna(x_test['OverallCond'].mean())
x_test['YearBuilt'] = x_test['YearBuilt'].fillna(x_test['YearBuilt'].mean())
x_test['YearRemodAdd'] = x_test['YearRemodAdd'].fillna(x_test['YearRemodAdd'].mean())
x_test['GarageCars'] = x_test['GarageCars'].fillna(x_test['GarageCars'].mean())
x_test['GarageArea'] = x_test['GarageArea'].fillna(x_test['GarageArea'].mean())
x_test['Fireplaces'] = x_test['Fireplaces'].fillna(x_test['Fireplaces'].mean())
x_test['GrLivArea'] = x_test['GrLivArea'].fillna(x_test['GrLivArea'].mean())
x_test['TotalBsmtSF'] = x_test['TotalBsmtSF'].fillna(x_test['TotalBsmtSF'].mean())
x_test['1stFlrSF'] = x_test['1stFlrSF'].fillna(x_test['1stFlrSF'].mean())
x_test['2ndFlrSF'] = x_test['2ndFlrSF'].fillna(x_test['2ndFlrSF'].mean())
x_test['LotArea'] = x_test['LotArea'].fillna(x_test['LotArea'].mean())
x_test['LotFrontage'] = x_test['LotFrontage'].fillna(x_test['LotFrontage'].mean())
x_test['FullBath'] = x_test['FullBath'].fillna(x_test['FullBath'].mean())
x_test['HalfBath'] = x_test['HalfBath'].fillna(x_test['HalfBath'].mean())
x_test['BsmtFullBath'] = x_test['BsmtFullBath'].fillna(x_test['BsmtFullBath'].mean())
x_test['PoolArea'] = x_test['PoolArea'].fillna(x_test['PoolArea'].mean())
# Out:
# C:\Users\armin\AppData\Local\Temp\ipykernel_11752\496194685.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test['ExterQual'] = x_test['ExterQual'].map({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po': 1})
# C:\Users\armin\AppData\Local\Temp\ipykernel_11752\496194685.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test['BsmtQual'] = x_test['BsmtQual'].map({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po': 1})
# ...

# %%
x_test = x_test.values

# %%
df = pd.read_csv("train_kaggle_two.csv")
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
#OverallQual,OverallCond,YearBuilt,YearRemodAdd,KitchenQual,ExterQual,BsmtQual,GarageCars,GarageArea,Fireplaces,FireplaceQu,GrLivArea,TotalBsmtSF,
#1stFlrSF,2ndFlrSF,LotArea,LotFrontage,FullBath,HalfBath,BsmtFullBath,KitchenQual,PoolArea,PoolQC,

#SalePrice

x = df[['OverallQual','OverallCond','YearBuilt','YearRemodAdd','ExterQual','BsmtQual','GarageCars','GarageArea','Fireplaces','FireplaceQu','GrLivArea','TotalBsmtSF','1stFlrSF','2ndFlrSF','LotArea','LotFrontage','FullBath','HalfBath','BsmtFullBath','PoolArea','KitchenQual']]
y = df['SalePrice']
x
# Out:
#       OverallQual  OverallCond  YearBuilt  YearRemodAdd ExterQual BsmtQual  \
# 0               7            5       2003          2003        Gd       Gd
# 1               6            8       1976          1976        TA       Gd
# 2               7            5       2001          2002        Gd       Gd
# 3               7            5       1915          1970        TA       TA
# 4               8            5       2000          2000        Gd       Gd
# ...           ...          ...        ...           ...       ...      ...
# 1455            6            5       1999          2000        TA       Gd
# 1456            6            6       1978          1988        TA       Gd
# 1457            7            9       1941          2006        Ex       TA
# 1458            5            6       1950          1996        TA       TA
# 1459            5            6       1965          1965        Gd       TA
#
# ...

# %%
x['ExterQual'] = x['ExterQual'].map({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po': 1})
x['BsmtQual'] = x['BsmtQual'].map({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po': 1})
x['FireplaceQu'] = x['FireplaceQu'].map({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po': 1})
x['KitchenQual'] = x['KitchenQual'].map({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po': 1})
x['ExterQual'] = x['ExterQual'].fillna(x['ExterQual'].mean())
x['BsmtQual'] = x['BsmtQual'].fillna(x['BsmtQual'].mean())
x['FireplaceQu'] = x['FireplaceQu'].fillna(x['FireplaceQu'].mean())
x['KitchenQual'] = x['KitchenQual'].fillna(x['KitchenQual'].mean())
x['OverallQual'] = x['OverallQual'].fillna(x['OverallQual'].mean())
x['OverallCond'] = x['OverallCond'].fillna(x['OverallCond'].mean())
x['YearBuilt'] = x['YearBuilt'].fillna(x['YearBuilt'].mean())
x['YearRemodAdd'] = x['YearRemodAdd'].fillna(x['YearRemodAdd'].mean())
x['GarageCars'] = x['GarageCars'].fillna(x['GarageCars'].mean())
x['GarageArea'] = x['GarageArea'].fillna(x['GarageArea'].mean())
x['Fireplaces'] = x['Fireplaces'].fillna(x['Fireplaces'].mean())
x['GrLivArea'] = x['GrLivArea'].fillna(x['GrLivArea'].mean())
x['TotalBsmtSF'] = x['TotalBsmtSF'].fillna(x['TotalBsmtSF'].mean())
x['1stFlrSF'] = x['1stFlrSF'].fillna(x['1stFlrSF'].mean())
x['2ndFlrSF'] = x['2ndFlrSF'].fillna(x['2ndFlrSF'].mean())
x['LotArea'] = x['LotArea'].fillna(x['LotArea'].mean())
x['LotFrontage'] = x['LotFrontage'].fillna(x['LotFrontage'].mean())
x['FullBath'] = x['FullBath'].fillna(x['FullBath'].mean())
x['HalfBath'] = x['HalfBath'].fillna(x['HalfBath'].mean())
x['BsmtFullBath'] = x['BsmtFullBath'].fillna(x['BsmtFullBath'].mean())
x['PoolArea'] = x['PoolArea'].fillna(x['PoolArea'].mean())
# Out:
# C:\Users\armin\AppData\Local\Temp\ipykernel_11752\1777818775.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['ExterQual'] = x['ExterQual'].map({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po': 1})
# C:\Users\armin\AppData\Local\Temp\ipykernel_11752\1777818775.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['BsmtQual'] = x['BsmtQual'].map({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po': 1})
# C:\Users\armin\AppData\Local\Temp\ipykernel_11752\1777818775.py:3: SettingWithCopyWarning:
# ...

# %%
x = x.values

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree = 5)
x_poly = poly.fit_transform(x)

model = LinearRegression()
model.fit(x_poly , y)

x_poly_test = poly.fit_transform(x_test)


y_pred = model.predict(x_poly_test)

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y , y_pred)
print(mse)

# %%
output = pd.DataFrame({
    'Id': x_idtest['Id'],
    'SalePrice': y_pred
})
output.to_csv('submission.csv', index=False)
